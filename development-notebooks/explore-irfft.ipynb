# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
# %load_ext autoreload

# %%
import numpy as np
import astropy.units as units
import matplotlib.pyplot as plt
import scipy.fft as fft
import scipy.sparse as sparse
import copy

# %%
# %autoreload 2

# %%
import dualpy as dp

# %%
NN = 2**6
omega = np.arange(NN)
X = (np.exp(-((omega-NN/2)/(NN/4))**2) + 0j) << units.dimensionless_unscaled
X = dp.seed(X, "X", initial_type="sparse")

# %%
plt.plot(omega, X.real);

# %%
N = 2*(NN-1)
t = np.arange(N)
x = dp.irfft(X)
# Out:
# For: X, -1 has become 0, <class 'dualpy.sparse_jacobians.SparseJacobian'>
# Going in, other is (126, 64), Jacobian is Jacobian of type <class 'dualpy.sparse_jacobians.SparseJacobian'>
# Dependent shape is (64,) <64>
# Independent shape is (64,)<64>
# Combined they are (64, 64) <4096>
# Dummies are (1,) and (1,)
# Units are d<>/d<> =
# data2d is (64, 64) with 64 numbers stored (1.6%)
# After rearrangement we have (126, 64) and (64, 64)
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-7-f85c6992e48e> in <module>
#       1 N = 2*(NN-1)
#       2 t = np.arange(N)
# ----> 3 x = dp.irfft(X)
#
# ~/python/dualpy/dualpy/user.py in irfft(x, axis)
#     741                 # sparse case under the hood).
#     742                 print(f"For: {name}, {axis} has become {jaxis}, {type(jacobian)}")
# --> 743                 result.jacobians[name] = jacobian.tensordot(
#     744                     D,
#     745                     axes=[[jaxis], [1]],
#
# ~/python/dualpy/dualpy/sparse_jacobians.py in tensordot(self, other, axes, dependent_unit)
#     479         result_raw = other @ new_csc
#     480         # Result is now a 2D dense matrix, reshape it to its full dimensionality
# --> 481         raise NotImplementedError("Needs checking and/or updating to use undo_rearrange")
#     482         rearranged_shapes[0][0] = other.shape[0]
#     483         result_ = np.reshape(result_raw, rearranged_shapes[0] + rearranged_shapes[1])
#
# NotImplementedError: Needs checking and/or updating to use undo_rearrange

# %%
plt.plot(t, x);

# %%
j_ana, j_num = dp.compute_jacobians_numerically(dp.irfft, args=[X])

# %%
r_ana = np.real(j_ana.jacobians["X"].todensearray()).value
r_num = np.real(j_num.jacobians["X"].todensearray()).value
i_ana = np.imag(j_ana.jacobians["X"].todensearray()).value
i_num = np.imag(j_num.jacobians["X"].todensearray()).value
delta_r = r_ana - r_num
delta_i = i_ana - i_num

# %%
plt.plot(r_ana.ravel(), r_num.ravel(), '.');

# %%
ratio = r_ana/r_num
plt.imshow(ratio);
plt.colorbar();

# %%
plt.plot(i_ana.ravel(), i_num.ravel(), '.');

# %%
plt.plot(delta_r.ravel(), '.')

# %%
plt.plot(delta_i.ravel(), '.')
