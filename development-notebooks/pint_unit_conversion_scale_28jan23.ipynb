# %%
# fmt: off
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
# %load_ext autoreload
# %load_ext lab_black
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pickle
from mls_scf_tools.mls_pint import ureg
plt.style.use("mls_scf")
def vdir(obj):
    return [x for x in dir(obj) if not x.startswith('__')]
# fmt: on

# %%
# %autoreload

# %%
from dualpy.dual_helpers import get_unit_conversion_scale

# %%
old_unit = ureg.s
new_unit = ureg.min

# %%
scale = get_unit_conversion_scale(old_unit, new_unit)

# %%
print(type(scale))
print(scale)
# Out:
# <class 'pint.quantity.build_quantity_class.<locals>.Quantity'>
# 0.016666666666666666 minute / second

# %%
f = new_unit.from_(old_unit)
print(type(f))
print(f)
# Out:
# <class 'pint.quantity.build_quantity_class.<locals>.Quantity'>
# 0.016666666666666666 minute

# %%
help(new_unit)
# Out:
# Help on Unit in module pint.unit object:
#
# class Unit(Unit)
#  |  Unit(*args, **kwargs)
#  |
#  |  Method resolution order:
#  |      Unit
#  |      Unit
#  |      pint.util.PrettyIPython
#  |      pint.util.SharedRegistryObject
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Unit:
#  |
#  |  __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#  |
#  |  __bytes__(self) -> 'bytes'
#  |
#  |  __complex__(self) -> 'complex'
#  |
#  |  __copy__(self) -> 'Unit'
#  |
#  |  __deepcopy__(self, memo) -> 'Unit'
#  |
#  |  __div__ = __truediv__(self, other)
#  |
#  |  __eq__(self, other) -> 'bool'
#  |      Return self==value.
#  |
#  |  __float__(self) -> 'float'
#  |
#  |  __format__(self, spec) -> 'str'
#  |      Default object formatter.
#  |
#  |  __ge__ lambda self, other
#  |
#  |  __gt__ lambda self, other
#  |
#  |  __hash__(self) -> 'int'
#  |      Return hash(self).
#  |
#  |  __init__(self, units: 'UnitLike') -> 'None'
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __int__(self) -> 'int'
#  |
#  |  __le__ lambda self, other
#  |
#  |  __lt__ lambda self, other
#  |
#  |  __mul__(self, other)
#  |
#  |  __ne__(self, other) -> 'bool'
#  |      Return self!=value.
#  |
#  |  __pow__(self, other) -> "'Unit'"
#  |
#  |  __rdiv__ = __rtruediv__(self, other)
#  |
#  |  __reduce__(self)
#  |      Helper for pickle.
#  |
#  |  __repr__(self) -> 'str'
#  |      Return repr(self).
#  |
#  |  __rmul__ = __mul__(self, other)
#  |
#  |  __rtruediv__(self, other)
#  |
#  |  __str__(self) -> 'str'
#  |      Return str(self).
#  |
#  |  __truediv__(self, other)
#  |
#  |  compare(self, other, op) -> 'bool'
#  |
#  |  compatible_units(self, *contexts)
#  |
#  |  format_babel(self, spec='', locale=None, **kwspec: 'Any') -> 'str'
#  |
#  |  from_(self, value, strict=True, name='value')
#  |      Converts a numerical value or quantity to this unit
#  |
#  |      Parameters
#  |      ----------
#  |      value :
#  |          a Quantity (or numerical value if strict=False) to convert
#  |      strict :
#  |          boolean to indicate that only quantities are accepted (Default value = True)
#  |      name :
#  |          descriptive name to use if an exception occurs (Default value = "value")
#  |
#  |      Returns
#  |      -------
#  |      type
#  |          The converted value as this unit
#  |
#  |  is_compatible_with(self, other: 'Any', *contexts: 'Union[str, Context]', **ctx_kwargs: 'Any') -> 'bool'
#  |      check if the other object is compatible
#  |
#  |      Parameters
#  |      ----------
#  |      other
#  |          The object to check. Treated as dimensionless if not a
#  |          Quantity, Unit or str.
#  |      *contexts : str or pint.Context
#  |          Contexts to use in the transformation.
#  |      **ctx_kwargs :
#  |          Values for the Context/s
#  |
#  |      Returns
#  |      -------
#  |      bool
#  |
#  |  m_from(self, value, strict=True, name='value')
#  |      Converts a numerical value or quantity to this unit, then returns
#  |      the magnitude of the converted value
#  |
#  |      Parameters
#  |      ----------
#  |      value :
#  |          a Quantity (or numerical value if strict=False) to convert
#  |      strict :
#  |          boolean to indicate that only quantities are accepted (Default value = True)
#  |      name :
#  |          descriptive name to use if an exception occurs (Default value = "value")
#  |
#  |      Returns
#  |      -------
#  |      type
#  |          The magnitude of the converted value
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from Unit:
#  |
#  |  debug_used
#  |
#  |  dimensionality
#  |      Returns
#  |      -------
#  |      dict
#  |          Dimensionality of the Unit, e.g. ``{length: 1, time: -1}``
#  |
#  |  dimensionless
#  |      Return True if the Unit is dimensionless; False otherwise.
#  |
#  |  systems
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from Unit:
#  |
#  |  __array_priority__ = 17
#  |
#  |  default_format = ''
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from pint.util.PrettyIPython:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from pint.util.SharedRegistryObject:
#  |
#  |  __new__(cls, *args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
