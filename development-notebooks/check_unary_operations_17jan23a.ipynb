# %%
# fmt: off
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
# %load_ext autoreload
# %load_ext lab_black
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import pickle
from mls_scf_tools.mls_pint import ureg
plt.style.use("mls_scf")
def vdir(obj):
    return [x for x in dir(obj) if not x.startswith('__')]
# fmt: on

# %%
# %autoreload 2
import dualpy as dp

# %%
u = ureg.km / ureg.m

# %%
x = np.linspace(0, 10, 101)[1:] * ureg.m
a = 1.0 / (1.0 * ureg.m)
b = 1.0 / (0.001 * ureg.km)

# %%
a = dp.seed(a, "a")
b = dp.seed(b, "b")

# %%
ya = np.log(a * x)
yb = np.log(b * x)
# Out:
# /users/livesey/python/dualpy/dualpy/base_jacobian.py:361: UserWarning: Got non-unit for Unit
#   warnings.warn("Got non-unit for Unit")

# %%
print(ya[-1], yb[-1])
# Out:
# 2.302585092994046 dimensionless 2.302585092994046 dimensionless

# %%
plt.plot(x, ya, ".")
plt.plot(x, yb)

# %%
ja = ya.jacobians["a"].todensearray().squeeze()
jb = yb.jacobians["b"].todensearray().squeeze()

# %%
print(ja[-1])
print(jb[-1])
# Out:
# 1.0 meter
# 0.001 kilometer

# %%
plt.plot(ja, ".")
plt.plot(jb)

# %%
print(ja.units, jb.units)
# Out:
# meter kilometer

# %%
plt.plot(ja, ".")
plt.plot(jb.to(ja.units))
plt.show()

# %%
print(j[0], jj[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 print(j[0], jj[0])
#
# NameError: name 'j' is not defined
